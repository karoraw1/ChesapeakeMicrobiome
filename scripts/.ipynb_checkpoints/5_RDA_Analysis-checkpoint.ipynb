# %%
# Probe & USGS Discharge Data
env_data_dir = "/Volumes/KeithSSD/ChesapeakeMicrobiome/data/environmental_raw_data"
env_data_file1 = paste(env_data_dir, "Transformed_WQVars_Hab_and_aDiv.txt", sep="/")
env_data_file2 = paste(env_data_dir, "merged_paired_water_quality_data.txt", sep="/")
env_data_1 <- read.delim(env_data_file1, row.names=1)
env_data_orig <- read.delim(env_data_file2, row.names=1)

extra_cols1 = c('ENSpie.1', 'FaithsPD.1', 'Observed.ASVs.1', 'Chao1', 'ACE',  'Observed.ASVs', 'qPCR.ct', 
                'Discharge_Susquehanna.15', 'SpringPeak', 'Station', 'ENSpie')
ENV.mini = env_data_1[,colnames(env_data_1)[which(!(colnames(env_data_1) %in% extra_cols1))]]

intcols = colnames(ENV.mini)[which(sapply(ENV.mini, class) == 'integer')]
for (ic in intcols)
    ENV.mini[,ic] = factor(ENV.mini[,ic])

colSums(is.na(ENV.mini))
# Out:
#                PHEO                  TN                  TP                CHLA
#                   0                   0                   0                   0
#                 DOP                 DON                NH4F                NO2F
#                   0                   0                   0                   0
#                NO3F                  PC                PO4F                  DO
#                   0                   0                   0                   0
#                  PH            SALINITY               WTEMP            Latitude
#                   0                   0                   0                   0
#             HABITAT WaterColumnPosition          LinearTime            FallPeak
#                   0                   0                   0                   0
#           cruise_id          SampleDate    Discharge_Sum.15            StatName
#                   0                   0                   0                   0
#          InvSimpson            FaithsPD
#                   0                   0

# %%
library(phyloseq)
#Taxonomy of each OTU
tax = read.delim("/Volumes/KeithSSD/ChesapeakeMicrobiome/data/otu_tables/taxa_table_with_OTUs.txt", row.names=1)
tax_mat = as.matrix(tax)
colnames(tax_mat)[1] <- 'Domain'
tax_mat[tax_mat == ""] <- NA

tree_file = "/Volumes/KeithSSD/ChesapeakeMicrobiome/data/phylogenetic_tree/RAxML_rootedTree.root.query_high_abund.ref.tre"
tree_obj = read_tree(tree_file, errorIfNULL=T)

# %%
#OTU table (shared file)
OTU1 = read.delim("../data/otu_tables/final_unrarefied_table.txt", row.names=1)
OTU2 = read.delim("../data/otu_tables/final_rarefied_table.tsv", row.names=1)

OTU.clean1 = OTU1[rownames(ENV.mini), ]
OTU.clean2 = OTU2[rownames(ENV.mini), ]

OTU.clean1.1 = as.matrix(OTU.clean1[,colSums(OTU.clean1) > 0])
OTU.clean2.1 = as.matrix(OTU.clean2[,colSums(OTU.clean2) > 0])

tax.clean1 = tax_mat[colnames(OTU.clean1.1), ]

tax.clean2 = tax_mat[colnames(OTU.clean2.1), ]
tree.clean2 = prune_taxa(taxa=colnames(OTU.clean2.1), tree_obj)

dim(OTU.clean1.1)
dim(tax.clean1)

dim(OTU.clean2.1)
dim(tax.clean2)
# Out:
# [1]   236 14307
# [1] 14307     7
# [1]  236 1432
# [1] 1432    7

# %%
physeq_1 = phyloseq(otu_table(OTU.clean1.1, taxa_are_rows = FALSE), 
                    tax_table(tax.clean1), ENV.mini)
physeq_1
physeq_2 = phyloseq(otu_table(OTU.clean2.1, taxa_are_rows = FALSE), 
                    tax_table(tax.clean2), ENV.mini, tree.clean2)
physeq_2
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 14307 taxa and 236 samples ]
# tax_table()   Taxonomy Table:    [ 14307 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1432 taxa and 236 samples ]
# tax_table()   Taxonomy Table:    [ 1432 taxa by 7 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1432 tips and 1431 internal nodes ]

# %%
library(vegan)
bc_dist = phyloseq::distance(physeq_1, method="bray", weighted=F)
wunifrac_dist = phyloseq::distance(physeq_2, method="unifrac", weighted=T)
# Out:
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-5

# %%
ENV.mini.2 <- subset(ENV.mini, select=-c(cruise_id, SampleDate, StatName, FaithsPD, InvSimpson))

cap.env.mini <- capscale(bc_dist ~ ., data=ENV.mini.2)
mod0.env.mini <- capscale(bc_dist ~ 1, data=ENV.mini.2)
step.env.mini <- ordiR2step(mod0.env.mini, scope=formula(cap.env.mini), direction ="forward", 
                           permutations = how(nperm = 99), trace = TRUE, R2permutations = 299)
# Out:
# Step: R2.adj= 0
# Call: bc_dist ~ 1
#
#                       R2.adjusted
# <All variables>        0.41154499
# + FallPeak             0.15100367
# + Discharge_Sum.15     0.13941257
# + WTEMP                0.13633533
# + PO4F                 0.09147819
# + HABITAT              0.08722184
# + TP                   0.07979964
# + SALINITY             0.07648887
# + Latitude             0.06334188
# + TN                   0.05378340
# + DON                  0.04803703
# + DO                   0.04737759
# + NO2F                 0.03997135
# + DOP                  0.03472591
# + PC                   0.03312748
# + CHLA                 0.03308869
# + NO3F                 0.03214401
# + PH                   0.03191615
# + LinearTime           0.03057680
# + PHEO                 0.02933175
# + WaterColumnPosition  0.02821196
# + NH4F                 0.02521205
# <none>                 0.00000000
#
#            Df    AIC      F Pr(>F)
# + FallPeak  1 975.98 41.757   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.1510037
# Call: bc_dist ~ FallPeak
#
#                       R2.adjusted
# <All variables>         0.4115450
# + SALINITY              0.2299123
# + HABITAT               0.2156858
# + Latitude              0.2141080
# + TN                    0.2042899
# + DON                   0.1963724
# + TP                    0.1868506
# + NO3F                  0.1861085
# + PC                    0.1822795
# + PO4F                  0.1810794
# + LinearTime            0.1806527
# + PH                    0.1788292
# + CHLA                  0.1773750
# + WaterColumnPosition   0.1772718
# + WTEMP                 0.1767611
# + DO                    0.1748611
# + PHEO                  0.1748261
# + Discharge_Sum.15      0.1739171
# + NH4F                  0.1731048
# + NO2F                  0.1688636
# + DOP                   0.1639946
# <none>                  0.1510037
#
#            Df    AIC      F Pr(>F)
# + SALINITY  1 954.56 24.307   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.2299123
# Call: bc_dist ~ FallPeak + SALINITY
#
#                       R2.adjusted
# <All variables>         0.4115450
# + HABITAT               0.2688775
# + PO4F                  0.2604702
# + LinearTime            0.2595720
# + TP                    0.2587619
# + Latitude              0.2581629
# + DO                    0.2553429
# + WaterColumnPosition   0.2549954
# + PH                    0.2537139
# + Discharge_Sum.15      0.2533219
# + CHLA                  0.2529396
# + NH4F                  0.2523609
# + NO3F                  0.2519853
# + TN                    0.2498433
# + WTEMP                 0.2484092
# + PHEO                  0.2480970
# + PC                    0.2467892
# + NO2F                  0.2464674
# + DOP                   0.2435494
# + DON                   0.2425340
# <none>                  0.2299123
#
#           Df    AIC      F Pr(>F)
# + HABITAT  2 944.67 7.0037   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.2688775
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT
#
#                       R2.adjusted
# <All variables>         0.4115450
# + Discharge_Sum.15      0.2942817
# + LinearTime            0.2941117
# + WTEMP                 0.2868296
# + DO                    0.2855711
# + NO3F                  0.2850626
# + TP                    0.2832077
# + PO4F                  0.2818564
# + Latitude              0.2818462
# + PC                    0.2799661
# + PHEO                  0.2798851
# + NO2F                  0.2790484
# + CHLA                  0.2779142
# + TN                    0.2772076
# + WaterColumnPosition   0.2763287
# + NH4F                  0.2761878
# + DOP                   0.2738117
# + PH                    0.2737240
# + DON                   0.2706892
# <none>                  0.2688775
#
#                    Df    AIC      F Pr(>F)
# + Discharge_Sum.15  1 937.57 9.0399   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.2942817
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15
#
#                       R2.adjusted
# <All variables>         0.4115450
# + LinearTime            0.3243153
# + DO                    0.3076799
# + PO4F                  0.3067971
# + NO3F                  0.3066713
# + TP                    0.3046966
# + Latitude              0.3043136
# + WTEMP                 0.3037583
# + CHLA                  0.3020273
# + PC                    0.3020131
# + PHEO                  0.3018228
# + TN                    0.3018066
# + NO2F                  0.3015858
# + WaterColumnPosition   0.3012963
# + NH4F                  0.3010669
# + DOP                   0.2995978
# + PH                    0.2992434
# + DON                   0.2965659
# <none>                  0.2942817
#
#              Df    AIC      F Pr(>F)
# + LinearTime  1 928.62 10.876   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3243153
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime
#
#                       R2.adjusted
# <All variables>         0.4115450
# + DO                    0.3374035
# + NO3F                  0.3365706
# + PO4F                  0.3354851
# + WTEMP                 0.3351953
# + TP                    0.3334185
# + Latitude              0.3328979
# + NO2F                  0.3327081
# + PC                    0.3322923
# + TN                    0.3318641
# + PHEO                  0.3317312
# + NH4F                  0.3312666
# + WaterColumnPosition   0.3309217
# + CHLA                  0.3304168
# + PH                    0.3293712
# + DOP                   0.3284656
# + DON                   0.3267381
# <none>                  0.3243153
#
#      Df    AIC      F Pr(>F)
# + DO  1 925.15 5.3482   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3374035
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO
#
#                       R2.adjusted
# <All variables>         0.4115450
# + PO4F                  0.3468785
# + WTEMP                 0.3468205
# + Latitude              0.3463602
# + NO3F                  0.3462797
# + NO2F                  0.3462413
# + TP                    0.3462392
# + WaterColumnPosition   0.3458281
# + PH                    0.3456172
# + TN                    0.3455431
# + PHEO                  0.3436323
# + NH4F                  0.3429745
# + PC                    0.3421099
# + CHLA                  0.3420137
# + DOP                   0.3406663
# + DON                   0.3397826
# <none>                  0.3374035
#
#        Df    AIC      F Pr(>F)
# + PO4F  1 922.85 4.1685   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3468785
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F
#
#                       R2.adjusted
# <All variables>         0.4115450
# + WTEMP                 0.3561709
# + Latitude              0.3555734
# + TN                    0.3555168
# + NO2F                  0.3554883
# + WaterColumnPosition   0.3554483
# + NO3F                  0.3553003
# + PH                    0.3550981
# + PHEO                  0.3530754
# + NH4F                  0.3521598
# + PC                    0.3516650
# + TP                    0.3516082
# + CHLA                  0.3514680
# + DOP                   0.3500100
# + DON                   0.3492983
# <none>                  0.3468785
#
#         Df    AIC      F Pr(>F)
# + WTEMP  1 920.57 4.1356   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3561709
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP
#
#                       R2.adjusted
# <All variables>         0.4115450
# + NO2F                  0.3650013
# + TN                    0.3648890
# + NO3F                  0.3647024
# + WaterColumnPosition   0.3643799
# + PH                    0.3632893
# + Latitude              0.3628941
# + PHEO                  0.3619313
# + NH4F                  0.3617063
# + PC                    0.3614388
# + TP                    0.3608179
# + CHLA                  0.3604992
# + DOP                   0.3593949
# + DON                   0.3586686
# <none>                  0.3561709
#
#        Df    AIC      F Pr(>F)
# + NO2F  1 918.41 4.0041   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3650013
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F
#
#                       R2.adjusted
# <All variables>         0.4115450
# + NO3F                  0.3735892
# + TN                    0.3731638
# + WaterColumnPosition   0.3729046
# + PH                    0.3723478
# + Latitude              0.3722752
# + PHEO                  0.3704068
# + NH4F                  0.3702841
# + PC                    0.3701215
# + TP                    0.3696203
# + CHLA                  0.3693943
# + DOP                   0.3684179
# + DON                   0.3674456
# <none>                  0.3650013
#
#        Df    AIC      F Pr(>F)
# + NO3F  1 916.29 3.9455   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3735892
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F
#
#                       R2.adjusted
# <All variables>         0.4115450
# + WaterColumnPosition   0.3818010
# + PH                    0.3811294
# + TN                    0.3808188
# + Latitude              0.3805371
# + PHEO                  0.3790703
# + NH4F                  0.3789548
# + PC                    0.3788563
# + TP                    0.3781979
# + DOP                   0.3774078
# + CHLA                  0.3770278
# + DON                   0.3758303
# <none>                  0.3735892
#
#                       Df    AIC      F Pr(>F)
# + WaterColumnPosition  1 914.26 3.8377   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.381801
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition
#
#                 R2.adjusted
# <All variables>   0.4115450
# + TN              0.3887048
# + PC              0.3871508
# + NH4F            0.3870984
# + Latitude        0.3869880
# + TP              0.3856725
# + PH              0.3854382
# + PHEO            0.3854104
# + CHLA            0.3852170
# + DOP             0.3850128
# + DON             0.3840394
# <none>            0.3818010
#
#      Df    AIC      F Pr(>F)
# + TN  1 912.68 3.3947   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3887048
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN
#
#                 R2.adjusted
# <All variables>   0.4115450
# + Latitude        0.3956165
# + PH              0.3920232
# + DOP             0.3919581
# + PHEO            0.3918566
# + CHLA            0.3916402
# + PC              0.3912961
# + TP              0.3911340
# + NH4F            0.3909073
# + DON             0.3903445
# <none>            0.3887048
#
#            Df    AIC      F Pr(>F)
# + Latitude  1 911.07 3.4124   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3956165
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN + Latitude
#
#                 R2.adjusted
# <All variables>   0.4115450
# + PH              0.3986648
# + PC              0.3986460
# + DOP             0.3986114
# + PHEO            0.3982001
# + CHLA            0.3979015
# + TP              0.3978992
# + DON             0.3975139
# + NH4F            0.3973157
# <none>            0.3956165
#
#      Df    AIC      F Pr(>F)
# + PH  1 910.88 2.0439   0.03 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3986648
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN + Latitude + PH
#
#                 R2.adjusted
# <All variables>   0.4115450
# + PC              0.4016716
# + PHEO            0.4012407
# + TP              0.4009793
# + CHLA            0.4008574
# + DOP             0.4007796
# + DON             0.4005749
# + NH4F            0.4001946
# <none>            0.3986648
#
#      Df    AIC      F Pr(>F)
# + PC  1 910.71 2.0289   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.4016716
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN + Latitude + PH + PC
#
#                 R2.adjusted
# <All variables>   0.4115450
# + TP              0.4040875
# + DON             0.4038784
# + DOP             0.4037887
# + PHEO            0.4036601
# + NH4F            0.4032322
# + CHLA            0.4026201
# <none>            0.4016716
#
#      Df    AIC      F Pr(>F)
# + TP  1 910.75 1.8186   0.02 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.4040875
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN + Latitude + PH + PC + TP
#
#                 R2.adjusted
# <All variables>   0.4115450
# + DON             0.4063358
# + DOP             0.4060006
# + PHEO            0.4059574
# + NH4F            0.4056926
# + CHLA            0.4046697
# <none>            0.4040875
#
#       Df    AIC     F Pr(>F)
# + DON  1 910.84 1.758   0.04 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.4063358
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN + Latitude + PH + PC + TP + DON
#
#                 R2.adjusted
# <All variables>   0.4115450
# + DOP             0.4083150
# + PHEO            0.4081882
# + NH4F            0.4076876
# + CHLA            0.4069901
# <none>            0.4063358
#
#       Df    AIC      F Pr(>F)
# + DOP  1 911.03 1.6615   0.05 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.408315
# Call: bc_dist ~ FallPeak + SALINITY + HABITAT + Discharge_Sum.15 +      LinearTime + DO + PO4F + WTEMP + NO2F + NO3F + WaterColumnPosition +      TN + Latitude + PH + PC + TP + DON + DOP
#
#                 R2.adjusted
# <All variables>   0.4115450
# + PHEO            0.4102395
# + NH4F            0.4091535
# + CHLA            0.4090023
# <none>            0.4083150
#
#        Df    AIC      F Pr(>F)
# + PHEO  1 911.24 1.6408   0.06 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
cap.env.mini.u <- capscale(wunifrac_dist ~ ., data=ENV.mini.2)
mod0.env.mini.u <- capscale(wunifrac_dist ~ 1, data=ENV.mini.2)
step.env.mini.u <- ordiR2step(mod0.env.mini.u, scope=formula(cap.env.mini.u), direction ="forward", 
                           permutations = how(nperm = 99), trace = TRUE, R2permutations = 299)
# Out:
# Step: R2.adj= 0
# Call: wunifrac_dist ~ 1
#
#                       R2.adjusted
# <All variables>        0.66541720
# + WTEMP                0.19500278
# + FallPeak             0.18761952
# + Discharge_Sum.15     0.17993789
# + HABITAT              0.15740413
# + PO4F                 0.15674763
# + TP                   0.13204878
# + CHLA                 0.12494174
# + DO                   0.12097218
# + SALINITY             0.11660370
# + WaterColumnPosition  0.09905562
# + Latitude             0.09187472
# + PC                   0.08690475
# + PH                   0.08548465
# + TN                   0.08089804
# + DOP                  0.07982172
# + NO2F                 0.07754671
# + DON                  0.07664268
# + NH4F                 0.07215289
# + NO3F                 0.05474504
# + LinearTime           0.03956748
# + PHEO                 0.02946481
# <none>                 0.00000000
#
#         Df    AIC      F Pr(>F)
# + WTEMP  1 683.09 50.374   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.1950028
# Call: wunifrac_dist ~ WTEMP
#
#                       R2.adjusted
# <All variables>         0.6654172
# + HABITAT               0.3590978
# + PO4F                  0.3238580
# + CHLA                  0.3180791
# + SALINITY              0.3138590
# + DO                    0.3001685
# + WaterColumnPosition   0.2966564
# + TP                    0.2936371
# + Latitude              0.2863944
# + PC                    0.2823408
# + PH                    0.2799375
# + TN                    0.2734484
# + NH4F                  0.2682073
# + NO2F                  0.2661061
# + DON                   0.2615618
# + LinearTime            0.2485573
# + FallPeak              0.2482888
# + NO3F                  0.2476254
# + DOP                   0.2459573
# + Discharge_Sum.15      0.2315438
# + PHEO                  0.2252219
# <none>                  0.1950028
#
#           Df    AIC      F Pr(>F)
# + HABITAT  2 639.33 26.015   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.3590978
# Call: wunifrac_dist ~ WTEMP + HABITAT
#
#                       R2.adjusted
# <All variables>         0.6654172
# + SALINITY              0.4479059
# + CHLA                  0.4269957
# + PC                    0.4131618
# + TN                    0.4100093
# + Latitude              0.4095031
# + PO4F                  0.4048517
# + NO3F                  0.4030875
# + DO                    0.4008481
# + FallPeak              0.3951763
# + LinearTime            0.3951422
# + PHEO                  0.3905719
# + TP                    0.3895441
# + DOP                   0.3887328
# + DON                   0.3845679
# + NO2F                  0.3813333
# + Discharge_Sum.15      0.3796841
# + WaterColumnPosition   0.3751533
# + NH4F                  0.3694825
# + PH                    0.3655964
# <none>                  0.3590978
#
#            Df    AIC      F Pr(>F)
# + SALINITY  1 611.28 31.372   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.4479059
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY
#
#                       R2.adjusted
# <All variables>         0.6654172
# + LinearTime            0.4847309
# + PO4F                  0.4846012
# + TP                    0.4820300
# + FallPeak              0.4720618
# + DO                    0.4713903
# + CHLA                  0.4706794
# + NO2F                  0.4703620
# + NO3F                  0.4694138
# + Discharge_Sum.15      0.4626936
# + Latitude              0.4611873
# + NH4F                  0.4586816
# + PC                    0.4578823
# + PHEO                  0.4577120
# + WaterColumnPosition   0.4561368
# + TN                    0.4549267
# + PH                    0.4529192
# + DOP                   0.4526022
# + DON                   0.4519549
# <none>                  0.4479059
#
#              Df   AIC     F Pr(>F)
# + LinearTime  1 599.2 14.14   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.4847309
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime
#
#                       R2.adjusted
# <All variables>         0.6654172
# + PO4F                  0.5209048
# + TP                    0.5174769
# + NO2F                  0.5077325
# + DO                    0.5072676
# + NO3F                  0.5064492
# + CHLA                  0.5054469
# + FallPeak              0.5051966
# + Latitude              0.4984628
# + Discharge_Sum.15      0.4979031
# + PC                    0.4966711
# + NH4F                  0.4963711
# + PHEO                  0.4954919
# + DOP                   0.4925604
# + WaterColumnPosition   0.4908600
# + PH                    0.4899449
# + TN                    0.4897256
# + DON                   0.4890028
# <none>                  0.4847309
#
#        Df    AIC      F Pr(>F)
# + PO4F  1 586.61 14.606   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.5209048
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F
#
#                       R2.adjusted
# <All variables>         0.6654172
# + NO2F                  0.5444426
# + DO                    0.5427435
# + NO3F                  0.5407608
# + FallPeak              0.5385131
# + CHLA                  0.5368685
# + Discharge_Sum.15      0.5360080
# + NH4F                  0.5343362
# + PHEO                  0.5326354
# + PC                    0.5323711
# + TP                    0.5310043
# + PH                    0.5269301
# + Latitude              0.5266431
# + WaterColumnPosition   0.5262951
# + DOP                   0.5262497
# + TN                    0.5258200
# + DON                   0.5253511
# <none>                  0.5209048
#
#        Df    AIC      F Pr(>F)
# + NO2F  1 578.39 10.089   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.5444426
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F
#
#                       R2.adjusted
# <All variables>         0.6654172
# + DO                    0.5659121
# + NO3F                  0.5643011
# + FallPeak              0.5599179
# + Discharge_Sum.15      0.5596064
# + CHLA                  0.5595806
# + NH4F                  0.5574703
# + PC                    0.5554249
# + PHEO                  0.5547191
# + TP                    0.5546450
# + TN                    0.5527520
# + PH                    0.5507717
# + DOP                   0.5501407
# + Latitude              0.5499367
# + DON                   0.5490166
# + WaterColumnPosition   0.5489558
# <none>                  0.5444426
#
#      Df    AIC     F Pr(>F)
# + DO  1 570.67 9.542   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.5659121
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO
#
#                       R2.adjusted
# <All variables>         0.6654172
# + Discharge_Sum.15      0.5814679
# + PH                    0.5789391
# + FallPeak              0.5783259
# + CHLA                  0.5778520
# + NO3F                  0.5777730
# + NH4F                  0.5748537
# + TN                    0.5741489
# + WaterColumnPosition   0.5734064
# + Latitude              0.5728857
# + TP                    0.5728474
# + PHEO                  0.5728472
# + DOP                   0.5712758
# + DON                   0.5699119
# + PC                    0.5698506
# <none>                  0.5659121
#
#                    Df   AIC      F Pr(>F)
# + Discharge_Sum.15  1 565.2 7.2673   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.5814679
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15
#
#                       R2.adjusted
# <All variables>         0.6654172
# + FallPeak              0.5960057
# + PH                    0.5945244
# + NO3F                  0.5936337
# + CHLA                  0.5934110
# + NH4F                  0.5906656
# + TN                    0.5900181
# + Latitude              0.5899435
# + WaterColumnPosition   0.5889188
# + PHEO                  0.5884696
# + DOP                   0.5875771
# + TP                    0.5866687
# + PC                    0.5857206
# + DON                   0.5853936
# <none>                  0.5814679
#
#            Df AIC      F Pr(>F)
# + FallPeak  1 560 6.9679   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.5960057
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak
#
#                       R2.adjusted
# <All variables>         0.6654172
# + NO3F                  0.6083079
# + CHLA                  0.6075985
# + PH                    0.6070663
# + TN                    0.6040898
# + WaterColumnPosition   0.6040292
# + NH4F                  0.6037359
# + DOP                   0.6026291
# + PHEO                  0.6025748
# + Latitude              0.6024305
# + TP                    0.6005180
# + PC                    0.6003395
# + DON                   0.5999102
# <none>                  0.5960057
#
#        Df    AIC      F Pr(>F)
# + NO3F  1 555.66 6.1026   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6083079
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F
#
#                       R2.adjusted
# <All variables>         0.6654172
# + PH                    0.6196224
# + CHLA                  0.6176970
# + WaterColumnPosition   0.6165138
# + NH4F                  0.6161518
# + DOP                   0.6159283
# + TN                    0.6152589
# + PHEO                  0.6149886
# + Latitude              0.6142121
# + PC                    0.6127160
# + TP                    0.6124583
# + DON                   0.6113487
# <none>                  0.6083079
#
#      Df    AIC     F Pr(>F)
# + PH  1 551.65 5.749   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6196224
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH
#
#                       R2.adjusted
# <All variables>         0.6654172
# + NH4F                  0.6277632
# + CHLA                  0.6272027
# + TN                    0.6264930
# + DOP                   0.6250243
# + Latitude              0.6245411
# + WaterColumnPosition   0.6240079
# + TP                    0.6237462
# + PHEO                  0.6235374
# + PC                    0.6231386
# + DON                   0.6224799
# <none>                  0.6196224
#
#        Df    AIC      F Pr(>F)
# + NH4F  1 549.04 4.3801   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6277632
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F
#
#                       R2.adjusted
# <All variables>         0.6654172
# + CHLA                  0.6340239
# + DOP                   0.6331679
# + Latitude              0.6329317
# + TN                    0.6325792
# + WaterColumnPosition   0.6321880
# + TP                    0.6321301
# + DON                   0.6311970
# + PHEO                  0.6311899
# + PC                    0.6298829
# <none>                  0.6277632
#
#        Df    AIC      F Pr(>F)
# + CHLA  1 547.28 3.5561   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6340239
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA
#
#                       R2.adjusted
# <All variables>         0.6654172
# + DOP                   0.6394781
# + WaterColumnPosition   0.6389539
# + TP                    0.6388230
# + Latitude              0.6386535
# + TN                    0.6384445
# + DON                   0.6372925
# + PHEO                  0.6360361
# + PC                    0.6350211
# <none>                  0.6340239
#
#       Df    AIC     F Pr(>F)
# + DOP  1 545.86 3.203   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6394781
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA + DOP
#
#                       R2.adjusted
# <All variables>         0.6654172
# + WaterColumnPosition   0.6443876
# + DON                   0.6441242
# + Latitude              0.6433249
# + TP                    0.6431022
# + TN                    0.6425300
# + PHEO                  0.6414949
# + PC                    0.6408032
# <none>                  0.6394781
#
#                       Df    AIC      F Pr(>F)
# + WaterColumnPosition  1 544.69 2.9629   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6443876
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA + DOP + WaterColumnPosition
#
#                 R2.adjusted
# <All variables>   0.6654172
# + DON             0.6489514
# + Latitude        0.6479340
# + TP              0.6476672
# + TN              0.6474547
# + PC              0.6459143
# + PHEO            0.6456670
# <none>            0.6443876
#
#       Df    AIC      F Pr(>F)
# + DON  1 543.67 2.8101   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6489514
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA + DOP + WaterColumnPosition + DON
#
#                 R2.adjusted
# <All variables>   0.6654172
# + TN              0.6552505
# + Latitude        0.6525472
# + TP              0.6525459
# + PC              0.6503968
# + PHEO            0.6502406
# <none>            0.6489514
#
#      Df    AIC      F Pr(>F)
# + TN  1 541.77 3.6176   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6552505
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA + DOP + WaterColumnPosition + DON + TN
#
#                 R2.adjusted
# <All variables>   0.6654172
# + Latitude        0.6596461
# + TP              0.6583547
# + PHEO            0.6573286
# + PC              0.6561981
# <none>            0.6552505
#
#            Df    AIC      F Pr(>F)
# + Latitude  1 540.79 2.7472   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6596461
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA + DOP + WaterColumnPosition + DON + TN + Latitude
#
#                 R2.adjusted
# <All variables>   0.6654172
# + TP              0.6628453
# + PHEO            0.6616105
# + PC              0.6610176
# <none>            0.6596461
#
#      Df    AIC      F Pr(>F)
# + TP  1 540.39 2.1946   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.6628453
# Call: wunifrac_dist ~ WTEMP + HABITAT + SALINITY + LinearTime + PO4F +      NO2F + DO + Discharge_Sum.15 + FallPeak + NO3F + PH + NH4F +      CHLA + DOP + WaterColumnPosition + DON + TN + Latitude +      TP
#
#                 R2.adjusted
# <All variables>   0.6654172
# + PHEO            0.6645403
# + PC              0.6641173
# <none>            0.6628453
#
#        Df    AIC      F Pr(>F)
# + PHEO  1 540.74 1.4973   0.11

# %%
bc_opt_vars = c('FallPeak', 'SALINITY', 'HABITAT', 'Discharge_Sum.15', 'LinearTime', 'DO')
wuf_opt_vars = c('WTEMP', 'HABITAT', 'SALINITY','LinearTime', 'PO4F', 'NO2F', 'DO', 'Discharge_Sum.15')

# %%
cons_ord_res = data.frame('wuf.adjr2'=c(), 'wuf.pval'=c(), 'wuf.constr'=c(), 
                          'bc.adjr2'=c(), 'bc.pval'=c(), 'bc.constr'=c())

cons_ord_res['full', 'bc.adjr2']  <- RsquareAdj(cap.env.mini)$adj.r.squared
cons_ord_res['full', 'bc.pval']  <- anova(cap.env.mini)["Pr(>F)"]['Model',]
cons_ord_res['full', 'bc.constr']  <- summary(cap.env.mini)$constr.chi/summary(cap.env.mini)$tot.chi

for (ind_var in bc_opt_vars){
    cap.env.ind <- capscale(bc_dist ~ ENV.mini.2[,ind_var], distance='bray')
    cons_ord_res[ind_var, 'bc.adjr2'] = RsquareAdj(cap.env.ind)$adj.r.squared
    cons_ord_res[ind_var, 'bc.pval'] = anova(cap.env.ind)["Pr(>F)"]['Model',]
    cons_ord_res[ind_var, 'bc.constr']  <- summary(cap.env.ind)$constr.chi/summary(cap.env.ind)$tot.chi
}

cap.env.mini.opt <- capscale(bc_dist ~., data=ENV.mini.2[,bc_opt_vars], distance='bray')
cons_ord_res['best', 'bc.adjr2']  <- RsquareAdj(cap.env.mini.opt)$adj.r.squared
cons_ord_res['best', 'bc.pval']  <- anova(cap.env.mini.opt)["Pr(>F)"]['Model',]
cons_ord_res['best', 'bc.constr']  <- summary(cap.env.mini.opt)$constr.chi/summary(cap.env.mini.opt)$tot.chi

cons_ord_res['full', 'wuf.adjr2']  <- RsquareAdj(cap.env.mini.u)$adj.r.squared
cons_ord_res['full', 'wuf.pval']  <- anova(cap.env.mini.u)["Pr(>F)"]['Model',]
cons_ord_res['full', 'wuf.constr']  <- summary(cap.env.mini.u)$constr.chi/summary(cap.env.mini.u)$tot.chi

for (ind_var in wuf_opt_vars){
    cap.env.ind <- capscale(wunifrac_dist ~ ENV.mini.2[,ind_var])
    cons_ord_res[ind_var, 'wuf.adjr2'] = RsquareAdj(cap.env.ind)$adj.r.squared
    cons_ord_res[ind_var, 'wuf.pval'] = anova(cap.env.ind)["Pr(>F)"]['Model',]
    cons_ord_res[ind_var, 'wuf.constr']  <- summary(cap.env.ind)$constr.chi/summary(cap.env.ind)$tot.chi
}

cap.env.mini.opt <- capscale(wunifrac_dist ~., data=ENV.mini.2[,wuf_opt_vars])
cons_ord_res['best', 'wuf.adjr2']  <- RsquareAdj(cap.env.mini.opt)$adj.r.squared
cons_ord_res['best', 'wuf.pval']  <- anova(cap.env.mini.opt)["Pr(>F)"]['Model',]
cons_ord_res['best', 'wuf.constr']  <- summary(cap.env.mini.opt)$constr.chi/summary(cap.env.mini.opt)$tot.chi

# %%
all_opt = unique(c(bc_opt_vars, wuf_opt_vars))
round(cons_ord_res[c(all_opt, 'best', 'full'),], 3)
# Out:
#                  bc.adjr2 bc.pval bc.constr wuf.adjr2 wuf.pval wuf.constr
# FallPeak         0.151    0.001   0.151        NA        NA       NA
# SALINITY         0.076    0.001   0.079     0.117     0.001    0.107
# HABITAT          0.087    0.001   0.093     0.157     0.001    0.147
# Discharge_Sum.15 0.139    0.001   0.140     0.180     0.001    0.164
# LinearTime       0.031    0.001   0.034     0.040     0.001    0.039
# DO               0.047    0.001   0.050     0.121     0.001    0.111
# WTEMP               NA       NA      NA     0.195     0.001    0.177
# PO4F                NA       NA      NA     0.157     0.001    0.143
# NO2F                NA       NA      NA     0.078     0.001    0.073
# best             0.337    0.001   0.350     0.581     0.001    0.533
# full             0.412    0.001   0.457     0.665     0.001    0.622

# %%
options(repr.plot.width=5, repr.plot.height=5)

cb.varpart.mini <- varpart(wunifrac_dist, 
                           ~ WTEMP + SALINITY + LinearTime,
                           ~ DO,
                           ~ NO2F,
                           ~ PO4F, data=ENV.mini)
cb.varpart.mini
plot(cb.varpart.mini)
flush.console()
# Out:
# Partition of squared  distance in dbRDA
#
# Call: varpart(Y = wunifrac_dist, X = ~WTEMP + SALINITY + LinearTime,
# ~DO, ~NO2F, ~PO4F, data = ENV.mini)
#
# Explanatory tables:
# X1:  ~WTEMP + SALINITY + LinearTime
# X2:  ~DO
# X3:  ~NO2F
# X4:  ~PO4F
#
# No. of explanatory tables: 4
# Total variation (SS): 19.36
# No. of observations: 236
#
# Partition table:
#                             Df R.square Adj.R.square Testable
# [aeghklno] = X1              3  0.36546      0.35725     TRUE
# [befiklmo] = X2              1  0.12460      0.12086     TRUE
# [cfgjlmno] = X3              1  0.08088      0.07695     TRUE
# [dhijkmno] = X4              1  0.16004      0.15645     TRUE
# [abefghiklmno] = X1+X2       4  0.46526      0.45600     TRUE
# [acefghjklmno] = X1+X3       4  0.44147      0.43180     TRUE
# [adeghijklmno] = X1+X4       4  0.48766      0.47878     TRUE
# [bcefgijklmno] = X2+X3       2  0.16299      0.15580     TRUE
# [bdefhijklmno] = X2+X4       2  0.19085      0.18391     TRUE
# [cdfghijklmno] = X3+X4       2  0.19510      0.18819     TRUE
# [abcefghijklmno] = X1+X2+X3  5  0.50723      0.49652     TRUE
# [abdefghijklmno] = X1+X2+X4  5  0.51612      0.50560     TRUE
# [acdefghijklmno] = X1+X3+X4  5  0.52147      0.51106     TRUE
# [bcdefghijklmno] = X2+X3+X4  3  0.22596      0.21595     TRUE
# [abcdefghijklmno] = All      6  0.55038      0.53860     TRUE
# Individual fractions
# [a] = X1 | X2+X3+X4          3               0.32266     TRUE
# [b] = X2 | X1+X3+X4          1               0.02754     TRUE
# [c] = X3 | X1+X2+X4          1               0.03300     TRUE
# [d] = X4 | X1+X2+X3          1               0.04209     TRUE
# [e]                          0               0.00022    FALSE
# [f]                          0              -0.00072    FALSE
# [g]                          0              -0.00096    FALSE
# [h]                          0               0.01806    FALSE
# [i]                          0               0.03718    FALSE
# [j]                          0               0.00751    FALSE
# [k]                          0               0.01391    FALSE
# [l]                          0               0.00042    FALSE
# [m]                          0               0.03475    FALSE
# [n]                          0              -0.00461    FALSE
# [o]                          0               0.00756    FALSE
# [p] = Residuals              0               0.46140    FALSE
# Controlling 2 tables X
# [ae] = X1 | X3+X4            3               0.32287     TRUE
# [ag] = X1 | X2+X4            3               0.32169     TRUE
# [ah] = X1 | X2+X3            3               0.34072     TRUE
# [be] = X2 | X3+X4            1               0.02776     TRUE
# [bf] = X2 | X1+X4            1               0.02682     TRUE
# [bi] = X2 | X1+X3            1               0.06472     TRUE
# [cf] = X3 | X1+X4            1               0.03228     TRUE
# [cg] = X3 | X2+X4            1               0.03204     TRUE
# [cj] = X3 | X1+X2            1               0.04051     TRUE
# [dh] = X4 | X2+X3            1               0.06015     TRUE
# [di] = X4 | X1+X3            1               0.07927     TRUE
# [dj] = X4 | X1+X2            1               0.04960     TRUE
# Controlling 1 table X
# [aghn] = X1 | X2             3               0.33515     TRUE
# [aehk] = X1 | X3             3               0.35485     TRUE
# [aegl] = X1 | X4             3               0.32233     TRUE
# [bfim] = X2 | X1             1               0.09875     TRUE
# [beik] = X2 | X3             1               0.07885     TRUE
# [befl] = X2 | X4             1               0.02746     TRUE
# [cfjm] = X3 | X1             1               0.07455     TRUE
# [cgjn] = X3 | X2             1               0.03494     TRUE
# [cfgl] = X3 | X4             1               0.03174     TRUE
# [dijm] = X4 | X1             1               0.12153     TRUE
# [dhjn] = X4 | X2             1               0.06305     TRUE
# [dhik] = X4 | X3             1               0.11124     TRUE
# ---
# Use function ‘dbrda’ to test significance of fractions of interest
# plot without title

# %%
set.seed(100)
wUF.nmds.3D = metaMDS(wunifrac_dist, method="NMDS", k=3, trymax=1000, trace=1)

options(repr.plot.width=3.5, repr.plot.height=3.5)
par(mfrow = c(1,1), mar = c(3.5,3.5,3,1), mgp = c(2, 0.6, 0), cex = 0.8, las = 1)
pears <- round(cor(wunifrac_dist, dist(wUF.nmds.3D$points), method = "pearson"),3)
plot(wunifrac_dist, dist(wUF.nmds.3D$points), main = "Shepard diagram of MDS", 
     xlab = "True UniFrac distance", ylab = "Distance in the reduced space", pch=18)
mtext(line = 0.1, text = paste0("Pearson correlation = ", pears), cex = 0.7)
# Out:
# Run 0 stress 0.1045495
# Run 1 stress 0.1045479
# ... New best solution
# ... Procrustes: rmse 0.000123459  max resid 0.0008571886
# ... Similar to previous best
# Run 2 stress 0.1045188
# ... New best solution
# ... Procrustes: rmse 0.00177683  max resid 0.02190201
# Run 3 stress 0.1044697
# ... New best solution
# ... Procrustes: rmse 0.003514682  max resid 0.05060401
# Run 4 stress 0.1045338
# ... Procrustes: rmse 0.004132203  max resid 0.05440587
# Run 5 stress 0.1045521
# ... Procrustes: rmse 0.004327495  max resid 0.05566888
# Run 6 stress 0.1044693
# ... New best solution
# ... Procrustes: rmse 0.0003584461  max resid 0.002342859
# ... Similar to previous best
# Run 7 stress 0.1045359
# ... Procrustes: rmse 0.00430577  max resid 0.05481624
# Run 8 stress 0.1044675
# ... New best solution
# ... Procrustes: rmse 0.0002500584  max resid 0.003281238
# ... Similar to previous best
# Run 9 stress 0.1045248
# ... Procrustes: rmse 0.003898764  max resid 0.05308142
# Run 10 stress 0.1045416
# ... Procrustes: rmse 0.004487856  max resid 0.0562486
# Run 11 stress 0.1044667
# ... New best solution
# ... Procrustes: rmse 0.0001146298  max resid 0.0008771901
# ... Similar to previous best
# Run 12 stress 0.1044716
# ... Procrustes: rmse 0.0003681562  max resid 0.003091755
# ... Similar to previous best
# Run 13 stress 0.104522
# ... Procrustes: rmse 0.003727842  max resid 0.05287641
# Run 14 stress 0.1045771
# ... Procrustes: rmse 0.002475363  max resid 0.01992802
# Run 15 stress 0.1044714
# ... Procrustes: rmse 0.0003684548  max resid 0.00288023
# ... Similar to previous best
# Run 16 stress 0.1045264
# ... Procrustes: rmse 0.003903997  max resid 0.05356405
# Run 17 stress 0.1044735
# ... Procrustes: rmse 0.0004047793  max resid 0.003298149
# ... Similar to previous best
# Run 18 stress 0.1287618
# Run 19 stress 0.1045466
# ... Procrustes: rmse 0.004543183  max resid 0.05659526
# Run 20 stress 0.104468
# ... Procrustes: rmse 0.000243991  max resid 0.002442838
# ... Similar to previous best
# *** Solution reached
# Plot with title “Shepard diagram of MDS”

# %%
n = 7
stress <- rep(0, n)
for (i in 1:n) {
    stress[i] <- metaMDS(wunifrac_dist, trymax=1000, k = i, trace=0)$stress
}
names(stress) <- paste(1:n, "Dim", sep="-")
stress
par(cex=0.8)
barplot(stress, ylab = "residual stress", xlab='# of axis used')
title('Weighted UniFrac NMDS Fit')
# Out:
#      1-Dim      2-Dim      3-Dim      4-Dim      5-Dim      6-Dim      7-Dim
# 0.35098401 0.17458831 0.10446772 0.07739968 0.05918844 0.04712473 0.03782191
# Plot with title “Weighted UniFrac NMDS Fit”

# %%
wuf_opt_vars1 = c('PO4F', 'DO', 'NO2F')
wuf_opt_vars2 = c('WTEMP', 'SALINITY', 'PO4F', 'DO', 'LinearTime', 'NO2F', 'HABITAT')
wuf_opt_vars3 = c('PO4F', 'DO', 'LinearTime', 'NO2F')

ENV.mini.3 = ENV.mini.2[,all_opt]

fit.swUF = envfit(wUF.nmds.3D, ENV.mini[,  wuf_opt_vars1])
fit.swUF
fit.swUF2 = envfit(wUF.nmds.3D, ENV.mini[, wuf_opt_vars], choices=c(3,2))
fit.swUF2
fit.swUF3 = envfit(wUF.nmds.3D, ENV.mini[, wuf_opt_vars3], choices=c(1,3))
fit.swUF3
# Out:
# ***VECTORS
#
#         NMDS1    NMDS2     r2 Pr(>r)
# PO4F -0.40970  0.91222 0.6269  0.001 ***
# DO    0.35757 -0.93389 0.4706  0.001 ***
# NO2F  0.21982 -0.97554 0.2021  0.001 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Permutation: free
# Number of permutations: 999
# ***VECTORS
#
#                     NMDS3    NMDS2     r2 Pr(>r)
# WTEMP            -0.73209  0.68120 0.0187  0.107
# SALINITY         -0.97763  0.21033 0.6978  0.001 ***
# LinearTime        0.88861 -0.45867 0.0812  0.001 ***
# PO4F              0.08248  0.99659 0.5039  0.001 ***
# NO2F             -0.66645 -0.74555 0.2818  0.001 ***
# DO                0.02935 -0.99957 0.3987  0.001 ***
# Discharge_Sum.15  0.70764 -0.70657 0.0766  0.001 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Permutation: free
# Number of permutations: 999
#
# ***FACTORS:
#
# Centroids:
#            NMDS3   NMDS2
# HABITAT1  0.0388  0.0628
# HABITAT2 -0.0555  0.0076
# HABITAT3 -0.0066 -0.0867
#
# Goodness of fit:
#             r2 Pr(>r)
# HABITAT 0.3465  0.001 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Permutation: free
# Number of permutations: 999
# ***VECTORS
#
#               NMDS1    NMDS3     r2 Pr(>r)
# PO4F       -0.98344  0.18122 0.1272  0.001 ***
# DO          0.99707  0.07646 0.0724  0.001 ***
# LinearTime -0.17394  0.98476 0.0600  0.001 ***
# NO2F        0.24443 -0.96967 0.1036  0.001 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Permutation: free
# Number of permutations: 999

# %%
options(repr.plot.width=5, repr.plot.height=5)
wUNFxyz = scores(wUF.nmds.3D, display="sites")

plot(wUNFxyz[,1], wUNFxyz[,2], main="UF 1:2", pch=20)
plot(fit.swUF, add=T)
plot(wUNFxyz[,1], wUNFxyz[,3], main="UF 1:3", pch=20)
plot(fit.swUF3, add=T)
# Out:
# Plot with title “UF 1:2”
# Plot with title “UF 1:3”

# %%
library(ggplot2)

mini.vectors.12 = c('PO4F', 'DO', 'NO2F')
mini.aes1 = c('HABITAT')
mini.aes2 = c('SALINITY', 'WTEMP')
plot.df.mini = cbind.data.frame(wUNFxyz, ENV.mini[,mini.aes1], env_data_orig[,mini.aes2])
colnames(plot.df.mini) <- c('NMDS1', 'NMDS2', 'NMDS3', 'Habitat', 'Salinity', 'Temp')
sapply(plot.df.mini, class)

spp.scrs <- as.data.frame(scores(fit.swUF, display = "vectors"))
spp.scrs <- apply(spp.scrs, MARGIN=2, FUN=function(x) {x*0.5})
spp.scrs

options(repr.plot.width=5, repr.plot.height=4)
sp2<-ggplot(plot.df.mini, aes(x=NMDS1, y=NMDS2)) + 
              geom_point(aes(color=Salinity, size=Temp, shape=Habitat)) + 
              scale_colour_gradient(low = "#A8A7A7", high = "#000000") + theme_classic() + 
              scale_size(range = c(0.5, 2.5))  + 
             annotate("segment", x = 0, xend = spp.scrs[,'NMDS1'],y = 0, yend = spp.scrs[,'NMDS2'], alpha=0.7,
                      colour = "black", size=0.9, arrow=arrow(length = unit(0.12, "inches")))  + 
              annotate('text', 
                        x= c(0.14, -0.2, 0), 
                        y= c(-0.27, 0.3, -0.2), 
                        label=c('DO', 'PO4', 'NO2'),
                        color='black', alpha=1.0, size=4)
sp2
# Out:
#     NMDS1     NMDS2     NMDS3   Habitat  Salinity      Temp
# "numeric" "numeric" "numeric"  "factor" "numeric" "numeric"
#      NMDS1       NMDS2
# PO4F -0.16219387  0.3611344
# DO    0.12265186 -0.3203360
# NO2F  0.04941022 -0.2192787
# plot without title

# %%
spp.scrs <- as.data.frame(scores(fit.swUF3, display = "vectors"))
spp.scrs <- apply(spp.scrs, MARGIN=2, FUN=function(x) {x*0.5})
spp.scrs
    
sp3 <- ggplot(plot.df.mini, aes(x=NMDS1, y=NMDS3)) + 
              geom_point(aes(color=Salinity, size=Temp, shape=Habitat)) + 
              scale_colour_gradient(low = "#A8A7A7", high = "#000000") + theme_classic() + 
              scale_size(range = c(0.5, 2.5))  + 
              annotate("segment", x = 0, xend = spp.scrs[,'NMDS1'],y = 0, yend = spp.scrs[,'NMDS3'], 
                      alpha=0.7, colour = "black", size=0.9, arrow=arrow(length = unit(0.12, "inches"))) + 
              annotate('text', 
                        x= c(0.13, -0.19, 0, 0.04), 
                        y= c(0.04, 0.08, -0.19, 0.16), 
                        label=c('DO', 'PO4', 'NO2', 'LinearTime'),
                        color='black', alpha=1.0, size=4)
sp3
# Out:
#            NMDS1       NMDS3
# PO4F       -0.17534097  0.03231061
# DO          0.13413168  0.01028595
# LinearTime -0.02129542  0.12056492
# NO2F        0.03933731 -0.15605282
# plot without title

# %%
as.dist(cor(sapply(plot.df.mini, as.numeric)[which(!is.na(plot.df.mini$Salinity)),]))
# Out:
#                 NMDS1        NMDS2        NMDS3      Habitat     Salinity
# NMDS2     0.003028647
# NMDS3     0.001626523 -0.004475102
# Habitat   0.078929223 -0.634556701 -0.271473321
# Salinity  0.090569826  0.222679577 -0.812928215  0.116362943
# Temp     -0.817141885  0.111496458 -0.098135488 -0.220223656  0.045661112

# %%
comp_orig = env_data_orig[which(!is.na(env_data_orig$DO)), 
                          c('NO2F', 'PO4F', 'DO', 'FallPeak', 'Latitude', 'WTEMP', 'WaterColumnPosition')]
colSums(!is.na(comp_orig))
# Out:
#                NO2F                PO4F                  DO            FallPeak
#                 233                 233                 233                 233
#            Latitude               WTEMP WaterColumnPosition
#                 233                 233                 233

# %%
library(MASS)
library(sfsmisc)

rr.do <- rlm(DO*-1 ~ Latitude + WTEMP + WaterColumnPosition, data = comp_orig, maxit=200)

summary(rr.do)
f.robftest(rr.do, var = "Latitude")
f.robftest(rr.do, var = "WTEMP")
f.robftest(rr.do, var = "WaterColumnPositionupper")

options(repr.plot.width=6, repr.plot.height=6)
par(mfrow = c(2,2))

plot(comp_orig$Latitude, comp_orig$DO, xlab='Latitude', ylab='DO')
plot(comp_orig$Latitude, rr.do$residuals, xlab='Latitude', ylab='DO residuals')
plot(comp_orig$WTEMP, comp_orig$DO, xlab='WTEMP', ylab='DO')
plot(comp_orig$WTEMP, rr.do$residuals, xlab='WTEMP', ylab='DO residuals')
# Out:
# Call: rlm(formula = DO * -1 ~ Latitude + WTEMP + WaterColumnPosition,
#     data = comp_orig, maxit = 200)
# Residuals:
#      Min       1Q   Median       3Q      Max
# -6.95355 -1.23284 -0.05035  1.15496  3.50475
#
# Coefficients:
#                          Value    Std. Error t value
# (Intercept)              -60.7343   6.3935    -9.4994
# Latitude                   1.3717   0.1669     8.2198
# WTEMP                      0.2093   0.0219     9.5715
# WaterColumnPositionupper  -4.3100   0.2676   -16.1060
#
# Residual standard error: 1.779 on 229 degrees of freedom
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = DO * -1 ~ Latitude + WTEMP + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 63.934, p-value = 6.333e-14
# alternative hypothesis: true Latitude is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = DO * -1 ~ Latitude + WTEMP + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 90.963, p-value < 2.2e-16
# alternative hypothesis: true WTEMP is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = DO * -1 ~ Latitude + WTEMP + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 264.74, p-value < 2.2e-16
# alternative hypothesis: true WaterColumnPositionupper is not equal to 0
# plot without title

# %%
rr.no2 <- rlm(NO2F ~ Latitude + FallPeak + WaterColumnPosition, data = comp_orig, maxit=200)

f.robftest(rr.no2, var = "Latitude")
f.robftest(rr.no2, var = "FallPeak")
f.robftest(rr.no2, var = "WaterColumnPositionupper")

options(repr.plot.width=6, repr.plot.height=6)
par(mfrow = c(2,2))
plot(comp_orig$Latitude, comp_orig$NO2F, xlab='Latitude', ylab='NO2F')
plot(comp_orig$Latitude, rr.no2$residuals, xlab='Latitude', ylab='NO2F residuals')
plot(comp_orig$FallPeak, comp_orig$NO2F, xlab='Seasonality', ylab='NO2F')
plot(comp_orig$FallPeak, rr.no2$residuals, xlab='Seasonality', ylab='NO2F')
# Out:
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = NO2F ~ Latitude + FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 35.779, p-value = 8.431e-09
# alternative hypothesis: true Latitude is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = NO2F ~ Latitude + FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 21.518, p-value = 5.895e-06
# alternative hypothesis: true FallPeak is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = NO2F ~ Latitude + FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 18.625, p-value = 2.368e-05
# alternative hypothesis: true WaterColumnPositionupper is not equal to 0
# plot without title

# %%
rr.po4 <- rlm(PO4F ~ Latitude*FallPeak + WaterColumnPosition, data = comp_orig, maxit=200)
summary(rr.po4)

f.robftest(rr.po4, var = "Latitude")
f.robftest(rr.po4, var = "FallPeak")
f.robftest(rr.po4, var = "Latitude:FallPeak")
f.robftest(rr.po4, var = "WaterColumnPositionupper")

options(repr.plot.width=6, repr.plot.height=6)
par(mfrow = c(2,2))
plot(comp_orig$Latitude, comp_orig$PO4F, xlab='Latitude', ylab='PO4F')
plot(comp_orig$Latitude, rr.po4$residuals, xlab='Latitude', ylab='PO4F residuals')
plot(comp_orig$FallPeak, comp_orig$PO4F, xlab='Seasonality', ylab='PO4F')
plot(comp_orig$FallPeak, rr.po4$residuals, xlab='Seasonality', ylab='PO4F residuals')
# Out:
# Call: rlm(formula = PO4F ~ Latitude * FallPeak + WaterColumnPosition,
#     data = comp_orig, maxit = 200)
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0343194 -0.0069653 -0.0001852  0.0073870  0.0767544
#
# Coefficients:
#                          Value   Std. Error t value
# (Intercept)              -0.2390  0.0450    -5.3148
# Latitude                  0.0068  0.0012     5.7504
# FallPeak                 -0.4040  0.0602    -6.7113
# WaterColumnPositionupper -0.0155  0.0017    -8.9400
# Latitude:FallPeak         0.0110  0.0016     6.9505
#
# Residual standard error: 0.01064 on 228 degrees of freedom
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = PO4F ~ Latitude * FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 33.422, p-value = 2.425e-08
# alternative hypothesis: true Latitude is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = PO4F ~ Latitude * FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 44.988, p-value = 1.545e-10
# alternative hypothesis: true FallPeak is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = PO4F ~ Latitude * FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 48.128, p-value = 4.086e-11
# alternative hypothesis: true Latitude:FallPeak is not equal to 0
# 	robust F-test (as if non-random weights)
#
# data:  from rlm(formula = PO4F ~ Latitude * FallPeak + WaterColumnPosition, from     data = comp_orig, maxit = 200)
# F = 83.557, p-value < 2.2e-16
# alternative hypothesis: true WaterColumnPositionupper is not equal to 0
# plot without title

# %%
resid_df = cbind(rr.no2$residuals, rr.po4$residuals, rr.do$residuals)
dim(resid_df)
dim(comp_orig)
rownames(resid_df) <- rownames(comp_orig)
colnames(resid_df) <- c('NO2F_residuals', 'PO4F_residuals',  'DO_residuals')
resid_df = as.data.frame(resid_df)

resid_file = paste(env_data_dir, 'environmental_residuals.txt', sep="/")
write.table(resid_df, file=resid_file, sep="\t")
# Out:
# [1] 233   3
# [1] 233   7

# %%
nti_fn = "../otu_data/dispersal_selection_data/ses_nti.RData"
load(nti_fn)
bnti_df = mntd_scores$comdistnt.obs.z[incl_samps, incl_samps]
bnti_dist = as.dist(bnti_df)

# %%
ps.rarefied = rarefy_even_depth(ps, rngseed=1, sample.size=0.9*min(sample_sums(ps)), replace=F)

# %%
BC.nmds.3D = metaMDS(OTU.clean2, distance="bray", k=3, trymax=1000)

# %%
OTU.UF = otu_table(as.matrix(OTU.clean), taxa_are_rows=FALSE)
tax.UF = tax_table(as.matrix(tax.clean))
meta.UF = sample_data(meta)
wUF.dist = UniFrac(physeq.tree, weighted=TRUE, normalized=TRUE)
BC.nmds

# %%
BC.nmds = metaMDS(OTU.clean, distance="bray", k=2, trymax=1000)
fit.BC = envfit(BC.nmds, meta[,c("AgeGroup", "ADGKG")])
fit.BC.OTU = envfit(BC.nmds, OTU.clean[,1:10])

# %%
adonis(BC.dist ~ AgeGroup*ADGKG, data = meta, permutations = 1000)
adonis(uwUF.dist ~ AgeGroup*ADGKG, data=meta, permutations = 1000)
permutest(disp.age, pairwise=TRUE, permutations=1000)
simper(OTU.clean, meta$AgeGroup, permutations=100)
kruskal.test(OTU.clean$Otu00001 ~ meta$AgeGroup)
#Note: These P-values have not been corrected from false discovery rate (fdr) yet.

# %%
KW.results = data.frame(read.csv("Age_krusk_simper.csv"))
#Remove non-significant
KW.results.signif = KW.results[KW.results$fdr_krusk_p.val < 0.05,]
#Order by OTU#
KW.results.signif = KW.results.signif[with(KW.results.signif, order(OTU)),]
head(KW.results.signif)
